# %% [markdown]
# What is the difference between a function and a method in Python?

# %% [markdown]
# function is a block of code that is designed to do a specific task that is defined outside of class

# %% [markdown]
# method is associated with object while function is not

# %%
# function
def add(a,b):
  return a+b
print(add(2,3))
# Out:
# 5

# %%
text = "apple"
text.upper()
# Out:
# 'APPLE'

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.

# %% [markdown]
# parameter are the values listed in function defination

# %% [markdown]
# arguement are the actual values passed when calling function

# %%
def sub(a,b): # function parameter
  return a-b
print(sub(4,3)) # function arguement
# Out:
# 1

# %% [markdown]
# What are the different ways to define and call a function in Python?

# %%
# simple function
def add(a,b):
  return a+b
print(add(5,6))
# Out:
# 11

# %%
# function with default argument
def add(a,b=5):
  return a+b
print(add(5))
# Out:
# 10

# %% [markdown]
# What is the purpose of the `return` statement in a Python function?

# %% [markdown]
# the purpose of return statment is to send the value back to the calling function and end the execution of the function

# %%
def add(a,b):
  return a+b
print(add(5,6))
# here a+b is returned and the function does not continue after return
# Out:
# 11

# %% [markdown]
# What are iterators in Python and how do they differ from iterables?

# %% [markdown]
# iterator - these are objects that can be looped over

# %% [markdown]
# iterables - htese keep track of current position and return one at a time using next() function

# %%
List =[1,2,3,4]
List_iterator = iter(List)
print(next(List_iterator))
print(next(List_iterator))
print(next(List_iterator))
print(next(List_iterator))
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# . Explain the concept of generators in Python and how they are defined.

# %% [markdown]
# Generators are special function that returns value one using yield

# %%
def gen():
  yield 1
  yield 2
  yield 3
for i in gen():
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
#  What are the advantages of using generators over regular functions?

# %% [markdown]
# it takees less memory,
# faster for large dataset and
# produce value on demand

# %%
def generate_numbers():
    for i in range(1000000):
        yield i

# %% [markdown]
# What is a lambda function in Python and when is it typically used?

# %% [markdown]
# small anonymous function written in one line
# used for simple operations

# %%
# example
square = lambda x: x**2
print(square(5))
# Out:
# 25

# %% [markdown]
# Explain the purpose and usage of the `map()` function in Python.

# %% [markdown]
# map() applies a function to every item in an iterable.

# %%
numbers = [1, 2, 3, 4]
squares = map(lambda x: x * x, numbers)

print(list(squares))
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

# %%
from functools import reduce

numbers = [1, 2, 3, 4]

# map
print(list(map(lambda x: x * 2, numbers)))

# filter
print(list(filter(lambda x: x % 2 == 0, numbers)))

# reduce
print(reduce(lambda x, y: x + y, numbers))
# Out:
# [2, 4, 6, 8]
# [2, 4]
# 10

# %% [markdown]
#  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# ![WhatsApp Image 2026-01-02 at 10.55.11 AM.jpeg](data:image/jpeg;base64,...)
